# %% [markdown]
# # echoX - 01: Feature Extraction & Spectro-Temporal Analysis
#
# Inspects raw waveforms, frequency spectrum, and acoustic artifacts between genuine human speech and synthetic vocoders.

# %%
import sys
from pathlib import Path
import numpy as np
import soundfile as sf
import matplotlib.pyplot as plt

sys.path.append("..")
from backend.app.services.audio_processor import AUDIO_PROCESSOR
from backend.app.core.config import TEST_SAMPLES_DIR

print("echoX Audio DSP Module Ready")

# %%
gen_path = TEST_SAMPLES_DIR / "genuine_human.wav"
clone_path = TEST_SAMPLES_DIR / "cloned_elevenlabs.wav"

gen_audio, sr = sf.read(gen_path)
clone_audio, sr = sf.read(clone_path)

print(f"Genuine: {len(gen_audio)} samples @ {sr}Hz")
print(f"Cloned:  {len(clone_audio)} samples @ {sr}Hz")
